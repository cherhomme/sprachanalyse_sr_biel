# %% [markdown]
# # Text aus den PDFs extrahieren
#
# Chatgpt schlägt folgenden Code vor:

# %%
import os
import fitz  # PyMuPDF

# %%
def pdf_to_txt(pdf_path, txt_path):
    # Open the PDF file
    pdf_document = fitz.open(pdf_path)
    
    # Initialize an empty string to store the extracted text
    text = ""
    
    # Iterate through each page in the PDF
    for page_num in range(pdf_document.page_count):
        page = pdf_document[page_num]
        
        # Extract text from the page
        text += page.get_text()
    
    # Close the PDF document
    pdf_document.close()
    
    # Write the extracted text to a text file
    with open(txt_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)

def process_pdfs(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)
    
    # Iterate through all PDF files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(input_folder, filename)
            txt_path = os.path.join(output_folder, os.path.splitext(filename)[0] + ".txt")
            
            # Convert PDF to text and save to a text file
            pdf_to_txt(pdf_path, txt_path)
            print(f"Converted {filename}")

# Provide the paths to the input and output folders
input_folder = '/Users/j/Documents/GitHub/abschlussarbeit/2013_2023_pv_pdf'
output_folder = '/Users/j/Documents/GitHub/abschlussarbeit/pv_textfiles'

# Process PDFs in the input folder and save text files in the output folder
process_pdfs(input_folder, output_folder)
# Out:
# Converted 15a_vom_16._November_2017_GV1.pdf
# Converted 12_08 vom 6. Juni 2019_GV.pdf
# Converted 02b_rat_Anhang Protokoll SR 02 vom 21. Februar 2013.pdf
# Converted 15a_rat_Protokoll_SR_15_vom_14._Oktober_20151.pdf
# Converted 14a vom 15.11.2018_GV.pdf
# Converted 01_01 vom 15. Januar 2020_GV.pdf
# Converted 05_03 vom 19. Februar 2020_GV_Anhang.pdf
# Converted 20_12 vom 19.September 2019_GV_Anhang.pdf
# Converted 04_03 vom 19. Februar 2020_GV.pdf
# Converted 06_04 vom 11. Februar 2021_GV.pdf
# Converted 11a_vom_12.10.2016_GV1.pdf
# Converted 25_17 vom 18. November 2021_Anhang.pdf
# Converted 03_02 vom 16. Januar 2020_GV.pdf
# Converted 08a_pra_rat_Protokoll_SR_30.06.16.pdf
# Converted 14a_rat_Protokoll SR 14 vom 20. November 2014.pdf
# Converted 03a_vom_23._Februar_2017_GV1.pdf
# Converted 11a_vom_21._September_2017_GV1.pdf
# Converted 09b_rat_Anhang Protokoll SR 09 vom 22. August 2013.pdf
# Converted 10a_rat_Protokoll SR 10 vom 19. September 2013.pdf
# ...
